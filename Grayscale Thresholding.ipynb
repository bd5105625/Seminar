# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
from matplotlib import cm
import argparse
import imutils

# %% [markdown]
# # Image treshold

# %%
abc = []
path = 'image/ILD/3'#folder path
allFileList = os.listdir(path)#file under the folder

# %%
imglist = []
filename = r'jpg'
# print(allFileList)
for file in allFileList:
    if file.endswith(filename):
        imglist.append(file)
#         print(file)
count = 0
for name in imglist:
    print(count)
    print(name)
    count = count + 1
# print(imglist[6])
# print(imglist[5])
# print(imglist[6])
# print(path)
# Out:
# 0
# FILE0.jpg
# 1
# FILE1.jpg
# 2
# FILE10.jpg
# 3
# FILE11.jpg
# 4
# FILE12.jpg
# 5
# FILE13.jpg
# 6
# FILE14.jpg
# 7
# FILE15.jpg
# 8
# FILE16.jpg
# 9
# FILE17.jpg
# 10
# FILE18.jpg
# 11
# FILE19.jpg
# 12
# FILE2.jpg
# 13
# FILE20.jpg
# 14
# FILE21.jpg
# 15
# FILE22.jpg
# 16
# FILE23.jpg
# 17
# FILE24.jpg
# 18
# FILE25.jpg
# 19
# FILE26.jpg
# 20
# FILE27.jpg
# 21
# FILE28.jpg
# 22
# FILE29.jpg
# 23
# FILE3.jpg
# 24
# FILE30.jpg
# 25
# FILE31.jpg
# 26
# FILE32.jpg
# 27
# FILE33.jpg
# 28
# FILE34.jpg
# 29
# FILE35.jpg
# 30
# FILE36.jpg
# 31
# FILE37.jpg
# 32
# FILE38.jpg
# 33
# FILE39.jpg
# 34
# FILE4.jpg
# 35
# FILE40.jpg
# 36
# FILE41.jpg
# 37
# FILE42.jpg
# 38
# FILE43.jpg
# 39
# FILE44.jpg
# 40
# FILE45.jpg
# 41
# FILE46.jpg
# 42
# FILE47.jpg
# 43
# FILE48.jpg
# 44
# FILE49.jpg
# 45
# FILE5.jpg
# 46
# FILE50.jpg
# 47
# FILE51.jpg
# 48
# FILE52.jpg
# 49
# FILE53.jpg
# 50
# FILE54.jpg
# 51
# FILE55.jpg
# 52
# FILE56.jpg
# 53
# FILE57.jpg
# 54
# FILE58.jpg
# 55
# FILE59.jpg
# 56
# ...

# %%
for file in imglist[66:-1]:
#     file = imglist[65]
    print(file)
    img = cv2.imread(path + "/" + file)
#     plt.imshow(img , 'gray')
    ret,thresh1 = cv2.threshold(img,180,255,cv2.THRESH_BINARY)
    temppath = path
    path = path + '/'+ 'gray'
    if not os.path.isdir(path):
        os.mkdir(path)
    distance = path + '/' + file.split('.')[0] + '_gray.jpg'
    path = temppath
    print(distance)
    cv2.imwrite(distance , thresh1)
#     cv2.imwrite((path + 'gray/' + file.split('.')[0] + '_gray.jpg'), )
# print(path + 'gray/' + file.split('.')[0] + '_gray.jpg')
# print(distance)
# cv2.imwrite("image/ILD/06753077/gray/ii.jpg" , thresh1)
plt.imshow(thresh1)
# Out:
# FILE69.jpg
# image/ILD/3/gray/FILE69_gray.jpg
# FILE7.jpg
# image/ILD/3/gray/FILE7_gray.jpg
# FILE70.jpg
# image/ILD/3/gray/FILE70_gray.jpg
# FILE71.jpg
# image/ILD/3/gray/FILE71_gray.jpg
# FILE72.jpg
# image/ILD/3/gray/FILE72_gray.jpg
# FILE73.jpg
# image/ILD/3/gray/FILE73_gray.jpg
# FILE74.jpg
# image/ILD/3/gray/FILE74_gray.jpg
# FILE75.jpg
# image/ILD/3/gray/FILE75_gray.jpg
# FILE76.jpg
# image/ILD/3/gray/FILE76_gray.jpg
# FILE77.jpg
# image/ILD/3/gray/FILE77_gray.jpg
# FILE78.jpg
# image/ILD/3/gray/FILE78_gray.jpg
# FILE79.jpg
# image/ILD/3/gray/FILE79_gray.jpg
# FILE8.jpg
# image/ILD/3/gray/FILE8_gray.jpg
# FILE80.jpg
# image/ILD/3/gray/FILE80_gray.jpg
# FILE81.jpg
# image/ILD/3/gray/FILE81_gray.jpg
# FILE82.jpg
# image/ILD/3/gray/FILE82_gray.jpg
# FILE83.jpg
# image/ILD/3/gray/FILE83_gray.jpg
# FILE84.jpg
# image/ILD/3/gray/FILE84_gray.jpg
# FILE85.jpg
# image/ILD/3/gray/FILE85_gray.jpg
# FILE86.jpg
# image/ILD/3/gray/FILE86_gray.jpg
# FILE87.jpg
# ...

# %% [markdown]
# # Image Thresholding in different type

# %%
img = cv2.imread('image/ILD/2/mask/FILE0_gray_masked.jpg', 0)
# img = cv2.imread('image/CT-7358-0009.' , 0)
ret,thresh1 = cv2.threshold(img,200,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)

titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

for i in range(0 , 6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()
# plt.imshow(thresh1 , 'gray')

# %%
plt.imshow(thresh5 , 'gray')
ret, temp = cv2.threshold(thresh5,0,255,cv2.THRESH_BINARY_INV)
plt.imshow(temp , 'gray')
plt.subplot(1 , 2 , 1),plt.imshow(thresh5 , 'gray')
plt.subplot(1 , 2 , 2),plt.imshow(temp , 'gray')
cv2.imwrite('image/ILD/2/mask/temp.jpg' , thresh5)
# Out:
# True

# %%
img = cv2.medianBlur(img , 5)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,-3)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)
titles = ['Original Image' , 'Normal Thresholding' , 'Mean Thresholding' , 'Gaussian Thresholding']
image = [img , thresh1 , th2 , th3]

for i in range(0 , 4):
    plt.subplot(2,2,i+1),plt.imshow(image[i] , 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
    
plt.show()

# %%
img = cv2.medianBlur(img , 5)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)
titles = ['Original Image' , 'Normal Thresholding' , 'Mean Thresholding' , 'Gaussian Thresholding']
image = [img , thresh1 , th2 , th3]

for i in range(0 , 4):
    plt.subplot(2,2,i+1),plt.imshow(image[i] , 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
    
plt.show()

# %%
img = cv2.imread('image/ILD/1/FILE0.jpg', 0)

ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

blur = cv2.GaussianBlur(img,(5,5),0)
ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

image = [img , th2 , th3]
titles = ['Original Image' , 'Otsu image' , 'Gaussian filter image']
for i in range(0 , 3):
#     plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
    plt.subplot(1 , 3 , i+1), plt.imshow(image[i] , 'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
    
plt.show()
